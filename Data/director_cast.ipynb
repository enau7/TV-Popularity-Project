# %%
import pandas as pd 
import numpy as np
data = pd.read_csv('/Users/christianmatthewgarduno/Downloads/streaming_titles_clean.csv')
data = data[["title", "director","cast","score",]]

# %% [markdown]
# Reducing the columns in the data set.

# %%
stats_data=data.sample(frac=.5,random_state=111)
norm_data = data.drop(stats_data.index)
director_scores = stats_data
cast_scores = stats_data.assign(cast=stats_data['cast'].str.split(',')).explode('cast')
cast_scores
# Out:
#                                                 title  \
# 5802  Dragons: Rescue Riders: Secrets of the Songwing
# 5802  Dragons: Rescue Riders: Secrets of the Songwing
# 5802  Dragons: Rescue Riders: Secrets of the Songwing
# 5802  Dragons: Rescue Riders: Secrets of the Songwing
# 5802  Dragons: Rescue Riders: Secrets of the Songwing
# ...                                               ...
# 5249                          The Lost Pirate Kingdom
# 5249                          The Lost Pirate Kingdom
# 5249                          The Lost Pirate Kingdom
# 5249                          The Lost Pirate Kingdom
# 5249                          The Lost Pirate Kingdom
#
#                       director               cast  score
# 5802  Greg Rankin, TJ Sullivan  Noah Kaye Bentley   27.0
# 5802  Greg Rankin, TJ Sullivan     Brennley Brown   27.0
# 5802  Greg Rankin, TJ Sullivan      Zach Callison   27.0
# 5802  Greg Rankin, TJ Sullivan      Nicolas Cantu   27.0
# 5802  Greg Rankin, TJ Sullivan       Skai Jackson   27.0
# ...                        ...                ...    ...
# 5249                       NaN      Mia Tomlinson   64.0
# 5249                       NaN      Kevin Howarth   64.0
# 5249                       NaN        Mark Gillis   64.0
# 5249                       NaN     George Watkins   64.0
# 5249                       NaN       Derek Jacobi   64.0
#
# [28604 rows x 4 columns]

# %% [markdown]
# Here I split the main dataset into two, and from there set two seperate group bys one for directors and one for the cast memebers. For the cast members I had to split them because they were in a list.

# %%
cast_scores['Number_MoviesShows'] = cast_scores['cast'].apply(lambda x: (cast_scores['cast'] == x).sum())
director_scores['Number_MoviesShows'] = director_scores['director'].apply(lambda x: (director_scores['director'] == x).sum())

# %% [markdown]
# This function is suppose to account the number of movies or shows a cast member has been in as well as for the director split.

# %%
director_scores=director_scores.groupby(['director','Number_MoviesShows' ])['score'].mean()
director_scores = pd.DataFrame(director_scores).reset_index()
director_scores.columns = ['director', 'Number_MoviesShows_dir','dir_average_score']
cast_scores2=cast_scores.groupby(['cast','Number_MoviesShows'])['score'].mean()
cast_count = pd.DataFrame(cast_scores2).reset_index()
cast_count.columns = ['cast', 'Number_MoviesShows_cast','cast_average_score']
cast_count
director_scores
# Out:
#                         director  Number_MoviesShows_dir  dir_average_score
# 0               20th_century_fox                       1               58.0
# 1                    A. L. Vijay                       1               12.0
# 2                   A.J. Murugan                       1               28.0
# 3                A.R. Murugadoss                       1               45.0
# 4                     Aanand Rai                       1               60.0
# ...                          ...                     ...                ...
# 2900          Antonio Margheriti                       1                3.0
# 2901     Raoul Walsh, Mario Bava                       1               17.0
# 2902          Álex de la Iglesia                       1               65.0
# 2903  Álvaro Delgado-Aparicio L.                       1               64.0
# 2904           Étienne Chatiliez                       1               20.0
#
# [2905 rows x 3 columns]

# %% [markdown]
# Converted from series due to group by back to dataframes. Cast_count is complete just needs to be merged with the other half of the parent dataset (don't have varaince at the moment). As well as Director Scores.

# %%
dir_tot = pd.merge(norm_data, director_scores, on='director')
total_data = pd.merge(dir_tot,cast_count,on='cast')
total_data
# Out:
#                                            title  \
# 0                      John Mulaney: New in Town
# 1                 John Mulaney: The Comeback Kid
# 2                  Jeff Dunham: Controlled Chaos
# 3                 Jeff Dunham: Relative Disaster
# 4                    Iliza Shlesinger: War Paint
# 5                     Iliza Shlesinger: Unveiled
# 6              Iliza Shlesinger: Confirmed Kills
# 7                         Jim Gaffigan: Obsessed
# 8                        Jim Gaffigan: King Baby
# 9                            Jim Gaffigan: Cinco
# 10                            A Year in Burgundy
# 11     Eddie Griffin: You Can Tell 'Em I Said It
# 12                          Ali Wong: Baby Cobra
# 13        Bill Burr: I'm Sorry You Feel That Way
# 14                          Bill Burr: Let It Go
# 15                     Marc Maron: End Times Fun
# 16  Nate Bargatze: The Greatest Average American
# 17                     Jim Jefferies: Intolerant
# 18            Kevin Hart: I'm a Grown Little Man
# 19                     Jenny Slate: Stage Fright
# 20                             The Hurt Business
# 21                                Dave Chappelle
# 22                      Joe Rogan: Strange Times
# 23    Chelsea Handler: Uganda Be Kidding Me Live
# 24              Dream Big: Engineering Our World
# 25                                  Dolphin Reef
# 26                             The Art of Skiing
# 27                                    Jungle Cat
# 28                               Secrets of Life
# 29                             The Living Desert
# 30                         The Vanishing Prairie
#
#                          director              cast  score  \
# 0                     Ryan Polito      John Mulaney   79.0
# 1                     Rhys Thomas      John Mulaney   84.0
# 2   Michael Simon, Matthew McNeil       Jeff Dunham   53.0
# 3                   Michael Simon       Jeff Dunham   37.0
# 4                     Jay Chapman  Iliza Shlesinger   40.0
# 5                     Steve Paley  Iliza Shlesinger   46.0
# 6               Bobcat Goldthwait  Iliza Shlesinger   57.0
# 7                     Jay Chapman      Jim Gaffigan   64.0
# 8                     Troy Miller      Jim Gaffigan   58.0
# 9                Jeannie Gaffigan      Jim Gaffigan   61.0
# 10                  David Kennard   Martine Saunier   20.0
# 11                      Jay Karas     Eddie Griffin   16.0
# 12                      Jay Karas          Ali Wong   77.0
# 13                      Jay Karas         Bill Burr   84.0
# 14                Shannon Hartman         Bill Burr   79.0
# 15                   Lynn Shelton        Marc Maron   48.0
# 16                    Troy Miller     Nate Bargatze   56.0
# 17                Scott Zabielski     Jim Jefferies   58.0
# 18                Shannon Hartman        Kevin Hart   71.0
# 19            Gillian Robespierre       Jenny Slate   53.0
# 20                     Vlad Yudin     Kevin Costner   29.0
# 21                    Stan Lathan    Dave Chappelle   61.0
# 22               Anthony Giordano         Joe Rogan   70.0
# 23                   James Yukich   Chelsea Handler   28.0
# 24              Greg MacGillivray      Jeff Bridges   40.0
# 25                  Keith Scholey   Natalie Portman   56.0
# 26                    Jack Kinney      John McLeish   47.0
# 27                    James Algar    Winston Hibler   14.0
# 28                    James Algar    Winston Hibler   11.0
# 29                    James Algar    Winston Hibler   50.0
# 30                    James Algar    Winston Hibler   32.0
#
#     Number_MoviesShows_dir  dir_average_score  Number_MoviesShows_cast  \
# 0                        4          50.500000                        1
# 1                        1          72.000000                        1
# 2                        1          32.000000                        4
# 3                        1          36.000000                        4
# 4                        5          27.400000                        1
# 5                        1          64.000000                        1
# 6                        2          41.000000                        1
# 7                        5          27.400000                        4
# 8                        2          28.000000                        4
# 9                        1          56.000000                        4
# 10                       1          62.000000                        1
# 11                       7          48.428571                        1
# 12                       7          48.428571                        1
# 13                       7          48.428571                        2
# 14                       3          44.666667                        2
# 15                       1          60.000000                        2
# 16                       2          28.000000                        1
# 17                       2          52.500000                        2
# 18                       3          44.666667                        4
# 19                       1          74.000000                        1
# 20                       4          36.750000                        3
# 21                       1          74.000000                        2
# 22                       1          67.000000                        1
# 23                       1          35.000000                        2
# 24                       1          45.000000                        5
# 25                       2          18.000000                        4
# 26                       4          37.750000                        1
# 27                       1          31.000000                        2
# 28                       1          31.000000                        2
# 29                       1          31.000000                        2
# 30                       1          31.000000                        2
#
#     cast_average_score
# 0            72.000000
# 1            72.000000
# 2            41.000000
# 3            41.000000
# 4            64.000000
# 5            64.000000
# 6            64.000000
# 7            52.750000
# 8            52.750000
# 9            52.750000
# 10           62.000000
# 11           73.000000
# 12           75.000000
# 13           77.000000
# 14           77.000000
# 15           54.500000
# 16           47.000000
# 17           72.000000
# 18           62.000000
# 19           74.000000
# 20           68.333333
# 21           54.500000
# 22           67.000000
# 23           42.000000
# 24           68.000000
# 25           53.500000
# 26           43.000000
# 27           19.500000
# 28           19.500000
# 29           19.500000
# 30           19.500000
