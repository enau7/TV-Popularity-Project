# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/streaming_titles.csv",dtype={'duration' :'string'})

# %%
# Removing duplicates

df = df.drop_duplicates(subset=['title'])

# %%
# Only take columns with a score value

df = df.loc[df['score'] > 0]

# %%
# Fixing issue with duration and rating column being swapped

badcols = df['rating'].str.contains("min") | df['rating'].str.contains("Seasons") | df['rating'].str.contains("Season")
df.loc[badcols,'duration'] = df.loc[badcols,'rating']
df.loc[badcols,'rating'] = np.NaN

df[badcols]
# Out:
#       show_id   type                              title    director  \
# 50        s51  Movie     Yashahime: Princess Half-Demon         NaN
# 108      s109  Movie                               Maze         NaN
# 263      s264  Movie                Trolls: TrollsTopia         NaN
# 397      s398  Movie        Gunfight at the O.K. Corral         NaN
# 510      s511  Movie  Citizen Jane: Battle for the City         NaN
# ...       ...    ...                                ...         ...
# 2908    s2909  Movie                     The Wrong Mans         NaN
# 2955    s2956  Movie                         Getting On         NaN
# 2959    s2960  Movie              Packed to the Rafters         NaN
# 18282   s5542  Movie                    Louis C.K. 2017  Louis C.K.
# 18535   s5795  Movie              Louis C.K.: Hilarious  Louis C.K.
#
#              cast                                   country  \
# 50            NaN                                     Japan
# 108           NaN  Ireland, United Kingdom, Germany, Sweden
# 263           NaN                             United States
# 397           NaN                             United States
# 510           NaN                             United States
# ...           ...                                       ...
# 2908          NaN                            United Kingdom
# 2955          NaN                            United Kingdom
# 2959          NaN                                 Australia
# 18282  Louis C.K.                             United States
# 18535  Louis C.K.                             United States
#
#                date_added  release_year rating   duration  \
# 50        October 9, 2021          2020    NaN  2 Seasons
# 108       October 1, 2021          2017    NaN     93 min
# 263     September 2, 2021          2020    NaN  4 Seasons
# 397        August 1, 2021          1957    NaN    136 min
# 510          July 1, 2021          2017    NaN     93 min
# ...                   ...           ...    ...        ...
# 2908    December 24, 2014          2013    NaN  2 Seasons
# 2955      January 7, 2014          2009    NaN  3 Seasons
# 2959     December 3, 2013          2008    NaN  6 Seasons
# 18282       April 4, 2017          2017    NaN     74 min
# 18535  September 16, 2016          2010    NaN     84 min
#
#                             listed_in  \
# 50                              Anime
# 108          Action, Adventure, Crime
# 263                      Family, Kids
# 397    Classics, Documentaries, Drama
# 510                     Documentaries
# ...                               ...
# 2908        Action, Adventure, Comedy
# 2955    Comedy, International, Sitcom
# 2959     Comedy, Drama, International
# 18282                          Movies
# 18535                          Movies
#
#                                              description streaming_service  \
# 50     Long-lost twins Towa and Setsuna reunite after...              hulu
# 108    Based on the incredible true story of the 1983...              hulu
# 263    Trolls: TrollsTopia! is the next chapter in th...              hulu
# 397    Dramatization of the legendary battle between ...              hulu
# 510    Chronicle of activist Jane Jacobs' battle with...              hulu
# ...                                                  ...               ...
# 2908   Lowly office workers Sam (Matthew Baynton) and...              hulu
# 2955   Care for the elderly is the least glamorous ar...              hulu
# 2959   Packed to the Rafters is an Australian family-...              hulu
# 18282  Louis C.K. muses on religion, eternal love, gi...           netflix
# 18535  Emmy-winning comedy writer Louis C.K. brings h...           netflix
#
#        score      imdbid
# 50      48.0  tt12287748
# 108     56.0   tt5752606
# 263     28.0  tt11714932
# 397     68.0   tt0050468
# 510     41.0   tt3699354
# ...      ...         ...
# 2908    82.0   tt2603596
# 2955    40.0   tt1468773
# 2959    24.0   tt1132600
# 18282   78.0   tt6736782
# 18535   83.0   tt1421373
#
# [226 rows x 15 columns]

# %%
# Converting duration to int

def dur_to_int(row):
    if type(row['duration']) != str:
        return np.NaN
    sp = ''.join([char for char in row['duration'] if char.isnumeric()])
    return int(sp)

df['duration'] = df.apply(dur_to_int,axis=1)

# %%
# Reducing and refactoring genre (complete code in genre_exploration.ipynb)

genre_reduction = {"Action & Adventure" : ["Action","Adventure"],
                   "Action-Adventure" : ["Action","Adventure"],
                   "Animals & Nature" : ["Nature"],
                   "Anime Features" : ["Anime"],
                   "Anime Series" : ["Anime"],
                   "Children & Family Movies" : ["Kids","Family"],
                   "Classic & Cult TV" : ["Classics","Cult"],
                   "Comedies" : ["Comedy"],
                   "Concert Film" : ["Music"],
                   "Crime TV Shows" : ["Crime"],
                   "Cult Movies" : ["Cult"],
                   "Documentaries" : ["Documentary"],
                   "Docuseries" : ["Documentary"],
                   "Dramas" : ["Drama"],
                   "Faith & Spirituality" : ["Faith and Spirituality"],
                   "Game Show / Competition" : ["Game Shows"],
                   "Historical" : ["History"],
                   "Horror Movies" : ["Horror"],
                   "International Movies" : ["International"],
                   "International TV Shows" : ["International"],
                   "Kid's TV" : ["Kids"],
                   "Late Night" : ["Talk Show"],
                   "LGBTQ Movies" : ["LGBTQ"],
                   "LGBTQ+" : ["LGBTQ"],
                   "Lifestyle & Culture": ["Lifestyle","Culture"],
                   "Music & Musicals" : ["Music", "Musical"],
                   "Music Videos and Concerts" : ["Music"],
                   "Reality TV" : ["Reality"],
                   "Romantic Comedy" : ["Romance", "Comedy"],
                   "Romantic TV Shows" : ["Romance"],
                   "Sci-Fi & Fantasy" : ["Science Fiction", "Fantasy"],
                   "Science & Nature TV" : ["Science & Technology","Nature"],
                   "Spanish-Language TV Shows" : ["Latino"],
                   "Sports Movies" : ["Sports"],
                   "Stand-Up Comedy" : ["Stand Up"],
                   "Stand-Up Comedy & Talk Shows" : ["Stand Up","Talk Show"],
                   "TV Action & Adventure" : ["Action", "Adventure"],
                   "TV Comedies" : ["Comedies"],
                   "TV Dramas" : ["Drama"],
                   "TV Horror" : ["Horror"],
                   "TV Mysteries" : ["Mystery"],
                   "TV Sci-Fi & Fantasy" : ["Science Fiction", "Fantasy"],
                   "TV Thrillers" : ["Thriller"],
                   "Talk Show and Variety" : ["Talk Show","Variety"],
                   "Teen TV Shows" : ["Teen"],
                   "Thrillers" : ["Thriller"],

                   "Arts" : ["Arts, Entertainment, and Culture"],
                   "Entertainment" : ["Arts, Entertainment, and Culture"],
                   "and Culture" : ["Arts, Entertainment, and Culture"]
                   }

df = df.reset_index(drop = True)

for i in range(len(df)):
    elem = df.loc[i,'listed_in']
    if type(elem) != str:
        continue
    splitted = elem.split(', ')
    for k in splitted:
        key = [k]
        if k in genre_reduction:
            key = genre_reduction[k]
        for l in key:
            df.loc[i,"genre." + l.replace(" ", "_")] = True

df.fillna({x : False for x in df.columns[pd.Series(df.columns).str.startswith("genre")]}, inplace=True)

df.drop(columns = ["streaming_service","show_id","date_added","listed_in"], inplace = True)

print(df.columns)

df.head(3)
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'release_year',
#        'rating', 'duration', 'description', 'score', 'imdbid', 'genre.Crime',
#        'genre.Drama', 'genre.Thriller', 'genre.Action', 'genre.Horror',
#        'genre.Science_Fiction', 'genre.Music', 'genre.Reality',
#        'genre.Romance', 'genre.Comedy', 'genre.Mystery', 'genre.Documentary',
#        'genre.History', 'genre.Teen', 'genre.Health_&_Wellness',
#        'genre.Lifestyle', 'genre.Culture', 'genre.Black_Stories', 'genre.News',
#        'genre.Latino', 'genre.Adventure', 'genre.Anime', 'genre.Talk_Show',
#        'genre.Sketch_Comedy', 'genre.Family', 'genre.Kids', 'genre.Classics',
#        'genre.LGBTQ', 'genre.Adult_Animation', 'genre.Sitcom',
#        'genre.Cooking_&_Food', 'genre.Sports', 'genre.Game_Shows',
#        'genre.International', 'genre.Cartoons', 'genre.Science_&_Technology',
#        'genre.Stand_Up', 'genre.Special_Interest', 'genre.Suspense',
#        'genre.TV_Shows', 'genre.Arts,_Entertainment,_and_Culture',
#        'genre.Variety', 'genre.Fantasy', 'genre.Young_Adult_Audience',
#        'genre.Animation', 'genre.Western', 'genre.Arthouse',
#        'genre.Unscripted', 'genre.Faith_and_Spirituality',
#        'genre.Military_and_War', 'genre.Independent_Movies',
#        'genre.British_TV_Shows', 'genre.Romantic_Movies', 'genre.Musical',
#        'genre.Comedies', 'genre.Classic_Movies', 'genre.Kids'_TV',
#        'genre.Nature', 'genre.Cult', 'genre.Korean_TV_Shows', 'genre.Movies',
#        'genre.Biographical', 'genre.Superhero', 'genre.Coming_of_Age',
#        'genre.Anthology', 'genre.Buddy', 'genre.Parody', 'genre.Spy/Espionage',
#        'genre.Survival', 'genre.Soap_Opera_/_Melodrama', 'genre.Dance',
#        'genre.Medical', 'genre.Disaster'],
#       dtype='object')
#     type         title director cast country  release_year rating  duration  \
# 0  Movie  Silent Night      NaN  NaN     NaN          2020    NaN      94.0
# 1  Movie  The Marksman      NaN  NaN     NaN          2021  PG-13     108.0
# 2  Movie          Gaia      NaN  NaN     NaN          2021      R      97.0
#
#                                          description  score  ...  \
# 0  Mark, a low end South London hitman recently r...   56.0  ...
# 1  A hardened Arizona rancher tries to protect an...   57.0  ...
# 2  A forest ranger and two survivalists with a cu...   63.0  ...
#
#   genre.Coming_of_Age  genre.Anthology  genre.Buddy  genre.Parody  \
# 0               False            False        False         False
# 1               False            False        False         False
# 2               False            False        False         False
#
#    genre.Spy/Espionage  genre.Survival  genre.Soap_Opera_/_Melodrama  \
# 0                False           False                         False
# 1                False           False                         False
# 2                False           False                         False
#
#    genre.Dance  genre.Medical  genre.Disaster
# 0        False          False           False
# 1        False          False           False
# 2        False          False           False
#
# [3 rows x 84 columns]

# %%
# Convert to csv

df.to_csv("data/streaming_titles_clean.csv",index=False)
