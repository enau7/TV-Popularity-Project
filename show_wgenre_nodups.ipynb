# %%
import pandas as pd
import numpy as np 
data = pd.read_csv('/Users/christianmatthewgarduno/Downloads/streaming_titles.csv')

# %%
no_dups_data = data.drop_duplicates(subset=['title'])
len(data)-len(no_dups_data)
has_score = no_dups_data.loc[no_dups_data['score'] > 0] 
has_score
# Out:
#       show_id     type                                           title  \
# 1          s2    Movie                                    Silent Night
# 2          s3    Movie                                    The Marksman
# 3          s4    Movie                                            Gaia
# 4          s5    Movie                                        Settlers
# 8          s9  TV Show                                          Queens
# ...       ...      ...                                             ...
# 23031   s1446    Movie                        X-Men Origins: Wolverine
# 23032   s1447    Movie  Night at the Museum: Battle of the Smithsonian
# 23033   s1448    Movie                                 Eddie the Eagle
# 23034   s1449    Movie                            Bend It Like Beckham
# 23035   s1450    Movie           Captain Sparky vs. The Flying Saucers
#
#               director                                               cast  \
# ...

# %%
genre_df = has_score
genre_df['genre'] = has_score['listed_in'].str.split(',').str[0]
genre_df.to_csv("genre_nodups.csv")
# Out:
# /var/folders/sn/lrb4f8354_x8v04bm0_5vzfm0000gn/T/ipykernel_83714/2030828218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre_df['genre'] = has_score['listed_in'].str.split(',').str[0]
